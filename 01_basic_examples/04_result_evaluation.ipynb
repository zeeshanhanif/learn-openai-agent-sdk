# %%
import nest_asyncio
nest_asyncio.apply()

# %%
import os
from dotenv import load_dotenv
import rich
from agents import Agent, Runner

# %%
load_dotenv()

api_key = os.getenv('OPENAI_API_KEY')
MODEL = "gpt-4o-mini"
# print(api_key)

# %%
agent = Agent(name="Hello World Agent", instructions="You are a helpful assistant", model=MODEL)

# %%
result = Runner.run_sync(agent,"Write a haiku about recursion in programming.")
rich.print(result)
# Out:
# RunResult(
#     input='Write a haiku about recursion in programming.',
#     new_items=[
#         MessageOutputItem(
#             agent=Agent(
#                 name='Hello World Agent',
#                 instructions='You are a helpful assistant',
#                 handoff_description=None,
#                 handoffs=[],
#                 model='gpt-4o-mini',
#                 model_settings=ModelSettings(
#                     temperature=None,
#                     top_p=None,
#                     frequency_penalty=None,
#                     presence_penalty=None,
#                     tool_choice=None,
#                     parallel_tool_calls=None,
#                     truncation=None,
#                     max_tokens=None,
#                     reasoning=None,
#                     metadata=None,
#                     store=None
#                 ),
#                 tools=[],
#                 mcp_servers=[],
#                 mcp_config={},
#                 input_guardrails=[],
#                 output_guardrails=[],
#                 output_type=None,
#                 hooks=None,
#                 tool_use_behavior='run_llm_again',
#                 reset_tool_choice=True
#             ),
#             raw_item=ResponseOutputMessage(
#                 id='msg_67fcb49b46848192aa87f35141586b7a04ef2b4f283dc73a',
#                 content=[
#                     ResponseOutputText(
#                         annotations=[],
#                         text='Calls stack like echoes,  \nLayers of thought intertwine—  \nEndless paths unfold.',
#                         type='output_text'
#                     )
#                 ],
#                 role='assistant',
#                 status='completed',
#                 type='message'
#             ),
#             type='message_output_item'
#         )
#     ],
#     raw_responses=[
#         ModelResponse(
#             output=[
#                 ResponseOutputMessage(
#                     id='msg_67fcb49b46848192aa87f35141586b7a04ef2b4f283dc73a',
#                     content=[
#                         ResponseOutputText(
#                             annotations=[],
#                             text='Calls stack like echoes,  \nLayers of thought intertwine—  \nEndless paths
# unfold.',
#                             type='output_text'
#                         )
#                     ],
#                     role='assistant',
#                     status='completed',
#                     type='message'
#                 )
#             ],
#             usage=Usage(requests=1, input_tokens=25, output_tokens=19, total_tokens=44),
#             referenceable_id='resp_67fcb49ad1108192be8e2d1707c2592304ef2b4f283dc73a'
#         )
#     ],
#     final_output='Calls stack like echoes,  \nLayers of thought intertwine—  \nEndless paths unfold.',
#     input_guardrail_results=[],
#     output_guardrail_results=[],
#     _last_agent=Agent(
#         name='Hello World Agent',
#         instructions='You are a helpful assistant',
#         handoff_description=None,
#         handoffs=[],
#         model='gpt-4o-mini',
#         model_settings=ModelSettings(
#             temperature=None,
#             top_p=None,
#             frequency_penalty=None,
#             presence_penalty=None,
#             tool_choice=None,
#             parallel_tool_calls=None,
#             truncation=None,
#             max_tokens=None,
#             reasoning=None,
#             metadata=None,
#             store=None
#         ),
#         tools=[],
#         mcp_servers=[],
#         mcp_config={},
#         input_guardrails=[],
#         output_guardrails=[],
#         output_type=None,
#         hooks=None,
#         tool_use_behavior='run_llm_again',
#         reset_tool_choice=True
#     )
# )
